# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristinaAndrius/SeleniumProject/blob/Pandas/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline
mpg = sns.load_dataset('mpg')
mpg.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino
# 5          70    usa           ford galaxie 500
# 6          70    usa           chevrolet impala
# 7          70    usa          plymouth fury iii
# 8          70    usa           pontiac catalina
# 9          70    usa         amc ambassador dpl

# %%
mpg.shape
# Out:
# (398, 9)

# %%
#1 Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių turi kokią akseleraciją. Šioje ir kitose užduotyse žaiskite su stiliais ir spalvomis, taip, kaip jums patinka.

sns.distplot(mpg['acceleration'], kde=False, bins=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
 #Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių turi kokius variklio tūrius.

sns.distplot(mpg['displacement'], kde=False, bins=10)

# %%
#3 Atspausdinkite histogramą, kurioje matytųsi, kokie yra cilindrų skaičiaus variantai.

sns.countplot(x='cylinders', data=mpg)

# %%
#4 Atspausdinkite histogramą, kurioje matytųsi, kiek yra pagaminimo metų variantų

sns.countplot(x='model_year', data=mpg)

# %%
#5 Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių lentelėje kokia šalis pagamino.

sns.countplot(x='origin', data=mpg)

# %%
#6 Atspausdinkite histogramą, kurioje matytųsi, koks kurioje šalyje pagamintų automobilių variklio tūrio vidurkis.

sns.scatterplot(x='acceleration', y='displacement', data=mpg, hue='origin')

# %%
#7 Atspausdinkite visas įmanomas sklaidos diagramas lentelėje, kur pagal taško spalvą matytumėm šalį gamintoją. Kokias tendencijas galima aiškiai išskirti?

sns.pairplot(data=mpg, hue='origin', diag_kind='hist')

# %%
#8 Atspausdinkite stulpelinę diagramą, 'origin' x 'mpg'. Pabandykite interpretuoti rezultatą.

sns.barplot(x='origin', y='mpg', data=mpg)

# %%
#9 Sukurkite koreliacijų matricą. Jos pagrindu atspausdinkite mozaikinę diagramą.

koreliacija = mpg.corr()
koreliacija
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
#
sns.heatmap(koreliacija, annot=True)

# %%
# Atspausdinkite sklaidos diagramų rinkinį, kuriame kiekviena lentelė pagal šalį rodytų 'acceleration' ir 'mpg' sąntykį.
seaborn.axisgrid.FacetGrid 
g = sns.FacetGrid(data = mpg, col='cylinders', row='origin')
g.map(sns.scatterplot, 'acceleration', 'mpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-b03205205a24> in <module>
#       1 # Atspausdinkite sklaidos diagramų rinkinį, kuriame kiekviena lentelė pagal šalį rodytų 'acceleration' ir 'mpg' sąntykį.
# ----> 2 seaborn.axisgrid.FacetGrid
#       3 g = sns.FacetGrid(data = mpg, col='cylinders', row='origin')
#       4 g.map(sns.scatterplot, 'acceleration', 'mpg')
#
# NameError: name 'seaborn' is not defined

# %%
df_1=mpg['cylinders'].value_counts()
print(df_1)
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64
