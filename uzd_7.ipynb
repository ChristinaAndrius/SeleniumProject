# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristinaAndrius/SeleniumProject/blob/Pandas/uzd_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
top_left=pd.read_excel('top1-25-1.xlsx')
print (top_left1)
# Out:
#                                        Track.Name    Artist.Name  \
# 0                                        Senorita   Shawn Mendes
# 1                                           China       Anuel AA
# 2                   boyfriend (with Social House)  Ariana Grande
# 3                 Beautiful People (feat. Khalid)     Ed Sheeran
# 4                     Goodbyes (Feat. Young Thug)    Post Malone
# 5               I Don't Care (with Justin Bieber)     Ed Sheeran
# 6                                          Ransom      Lil Tecca
# 7                               How Do You Sleep?      Sam Smith
# 8                           Old Town Road - Remix      Lil Nas X
# 9                                         bad guy  Billie Eilish
# 10                                       Callaita      Bad Bunny
# 11          Loco Contigo (feat. J. Balvin & Tyga)       DJ Snake
# 12                              Someone You Loved  Lewis Capaldi
# ...

# %%
top_right=pd.read_excel('top1-25-2.xlsx')
print (top_right)
# Out:
#                                        Track.Name  Beats.Per.Minute  Energy  \
# 0                                        Senorita               117      55
# 1                                           China               105      81
# 2                   boyfriend (with Social House)               190      80
# 3                 Beautiful People (feat. Khalid)                93      65
# 4                     Goodbyes (Feat. Young Thug)               150      65
# 5               I Don't Care (with Justin Bieber)               102      68
# 6                                          Ransom               180      64
# 7                               How Do You Sleep?               111      68
# 8                           Old Town Road - Remix               136      62
# 9                                         bad guy               135      43
# 10                                       Callaita               176      62
# ...

# %%
bottom_left=pd.read_excel('top26-50-1.xlsx')
print(bottom_left)
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                 If I Can't Have You      Shawn Mendes
# 1                                        Dance Monkey       Tones and I
# 2                                            It's You         Ali Gatie
# 3                                           Con Calma      Daddy Yankee
# 4                                       QUE PRETENDES          J Balvin
# 5                                            Takeaway  The Chainsmokers
# 6                                             7 rings     Ariana Grande
# 7                                            0.958333            Maluma
# 8           The London (feat. J. Cole & Travis Scott)        Young Thug
# 9                                   Never Really Over        Katy Perry
# 10  Summer Days (feat. Macklemore & Patrick Stump ...     Martin Garrix
# 11                                         Otro Trago              Sech
# ...

# %%
bottom_right=pd.read_excel('top26-50-2.xlsx')
print(bottom_right)
# Out:
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 0                124      82            69              -4        13
# 1                 98      59            82              -6        18
# 2                 96      46            73              -7        19
# 3                 94      86            74              -3         6
# 4                 93      79            64              -4        36
# 5                 85      51            29              -8        10
# 6                140      32            78             -11         9
# 7                 96      71            78              -5         9
# 8                 98      59            80              -7        13
# 9                100      88            77              -5        32
# 10               114      72            66              -7        14
# 11               176      70            75              -5        11
# 12               152      82            72              -5        36
# ...

# %%
sujungta_apacia = pd.concat(([bottom_right, bottom_left])).drop_duplicates(subset=None, keep=False, inplace=False, ignore_index=False)
print(sujungta_apacia)
# Out:
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 0              124.0    82.0          69.0            -4.0      13.0
# 1               98.0    59.0          82.0            -6.0      18.0
# 2               96.0    46.0          73.0            -7.0      19.0
# 3               94.0    86.0          74.0            -3.0       6.0
# 4               93.0    79.0          64.0            -4.0      36.0
# 5               85.0    51.0          29.0            -8.0      10.0
# 6              140.0    32.0          78.0           -11.0       9.0
# 7               96.0    71.0          78.0            -5.0       9.0
# 8               98.0    59.0          80.0            -7.0      13.0
# 9              100.0    88.0          77.0            -5.0      32.0
# 10             114.0    72.0          66.0            -7.0      14.0
# 11             176.0    70.0          75.0            -5.0      11.0
# 12             152.0    82.0          72.0            -5.0      36.0
# ...

# %%
top_right=pd.read_excel('top1-25-2.xlsx')
top_left=pd.read_excel('top1-25-1.xlsx')
bottom_right=pd.read_excel('top26-50-2.xlsx')
bottom_left=pd.read_excel('top26-50-1.xlsx')

sujungta_apacia_2 = pd.concat(([bottom_right, bottom_left]), axis=1)
sujungtas_virsus_pagal_column_name = pd.merge(top_right,top_left,on=['Track.Name','Popularity'])
viskas_sujungta = pd.concat([sujungtas_virsus_pagal_column_name,sujungta_apacia_2])
print(viskas_sujungta)
# Out:
#                                            Track.Name  Beats.Per.Minute  \
# 0                                            Senorita               117
# 1                                               China               105
# 2                       boyfriend (with Social House)               190
# 3                     Beautiful People (feat. Khalid)                93
# 4                         Goodbyes (Feat. Young Thug)               150
# 5                   I Don't Care (with Justin Bieber)               102
# 6                                              Ransom               180
# 7                                   How Do You Sleep?               111
# 8                               Old Town Road - Remix               136
# 9                                             bad guy               135
# 10                                           Callaita               176
# 11              Loco Contigo (feat. J. Balvin & Tyga)                96
# ...

# %%
import numpy as np
index=pd.merge(sujungtas_virsus_pagal_column_name, sujungta_apacia_2)
index.reset_index()
index.index=np.arange(1,len(index)+1)
print(index.index)
# Out:
# Int64Index([], dtype='int64')

# %%
7 uzduotis

data[data['Genre'].isnull() | data['Popularity'].isnull()]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cac14db43f25> in <module>
# ----> 1 bottom_left.head(3)
#
# NameError: name 'bottom_left' is not defined

# %%
import pandas as pd
top_left=pd.read_excel('top1-25-1.xlsx')
top_left.head(3)
print(top_left)
#print as many cells from the top of data or bottom
print(top_left.head(3))
print(top_left.tail(3))
# Out:
#                                        Track.Name    Artist.Name  \
# 0                                        Senorita   Shawn Mendes
# 1                                           China       Anuel AA
# 2                   boyfriend (with Social House)  Ariana Grande
# 3                 Beautiful People (feat. Khalid)     Ed Sheeran
# 4                     Goodbyes (Feat. Young Thug)    Post Malone
# 5               I Don't Care (with Justin Bieber)     Ed Sheeran
# 6                                          Ransom      Lil Tecca
# 7                               How Do You Sleep?      Sam Smith
# 8                           Old Town Road - Remix      Lil Nas X
# 9                                         bad guy  Billie Eilish
# 10                                       Callaita      Bad Bunny
# 11          Loco Contigo (feat. J. Balvin & Tyga)       DJ Snake
# 12                              Someone You Loved  Lewis Capaldi
# ...

# %%
#read headers
top_left=pd.read_excel('top1-25-1.xlsx')
print(top_left.columns)
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Popularity'], dtype='object')

# %%
#print column by its header name/ from selected 0:5 e.g.

print(top_left['Track.Name'])
print(top_left['Track.Name'][0:5])
#aspasdinti kelis stulpelius pagal pavadinima

print(top_left[['Track.Name', 'Popularity']])
# Out:
# 0                                          Senorita
# 1                                             China
# 2                     boyfriend (with Social House)
# 3                   Beautiful People (feat. Khalid)
# 4                       Goodbyes (Feat. Young Thug)
# 5                 I Don't Care (with Justin Bieber)
# 6                                            Ransom
# 7                                 How Do You Sleep?
# 8                             Old Town Road - Remix
# 9                                           bad guy
# 10                                         Callaita
# 11            Loco Contigo (feat. J. Balvin & Tyga)
# 12                                Someone You Loved
# 13                               Otro Trago - Remix
# 14         Money In The Grave (Drake ft. Rick Ross)
# 15                        No Guidance (feat. Drake)
# 16                                       LA CANCION
# 17    Sunflower - Spider-Man: Into the Spider-Verse
# ...

# %%
#read  rows 1-3 according to indexes

top_left.iloc[1:3]
# Out:
#                       Track.Name    Artist.Name           Genre  Popularity
# 1                          China       Anuel AA  reggaeton flow        92.0
# 2  boyfriend (with Social House)  Ariana Grande       dance pop        85.0

# %%
#read specific data location( row,  column)

top_left.iloc[2,1]
# Out:
# 'Ariana Grande'

# %%
# for index, row in df.iterrow funkcija iteruoti per / print(index,row['Nametotop_left.iterrows(3)

top_left.iterrows(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-91302ddb3f1c> in <module>
#       1 # for index, row in df.iterrow funkcija iteruoti per / print(index,row['Nametotop_left.iterrows(3)
#       2
# ----> 3 top_left.iterrows(2)
#
# TypeError: iterrows() takes 1 positional argument but 2 were given

# %%
print(top_left.loc[top_left['Popularity']=='91'])
# Out:
# Empty DataFrame
# Columns: [Track.Name, Artist.Name, Genre, Popularity]
# Index: []

# %%
top_left.describe()
# Out:
#        Popularity
# count   23.000000
# mean    88.782609
# std      4.100516
# min     79.000000
# 25%     86.500000
# 50%     90.000000
# 75%     91.500000
# max     95.000000

# %%
top_left.sort_values('Popularity',ascending=False)  #surusiuoti pagal stulpeli, ascending, descending, arba nereikia nieko rasyti
# Out:
#                                        Track.Name    Artist.Name  \
# 9                                         bad guy  Billie Eilish
# 4                     Goodbyes (Feat. Young Thug)    Post Malone
# 10                                       Callaita      Bad Bunny
# 6                                          Ransom      Lil Tecca
# 1                                           China       Anuel AA
# 14       Money In The Grave (Drake ft. Rick Ross)          Drake
# 23                                Soltera - Remix          Lunay
# 21                                         Panini      Lil Nas X
# 20                            Piece Of Your Heart         MEDUZA
# 19                                    Truth Hurts          Lizzo
# 17  Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 16                                     LA CANCION       J Balvin
# 7                               How Do You Sleep?      Sam Smith
# ...

# %%
top_left.sort_values(['Track.Name','Popularity']) ## paimant kelis stulpelius
# Out:
#                                        Track.Name    Artist.Name  \
# 3                 Beautiful People (feat. Khalid)     Ed Sheeran
# 10                                       Callaita      Bad Bunny
# 1                                           China       Anuel AA
# 4                     Goodbyes (Feat. Young Thug)    Post Malone
# 7                               How Do You Sleep?      Sam Smith
# 5               I Don't Care (with Justin Bieber)     Ed Sheeran
# 16                                     LA CANCION       J Balvin
# 18                                         Lalala            Y2K
# 11          Loco Contigo (feat. J. Balvin & Tyga)       DJ Snake
# 14       Money In The Grave (Drake ft. Rick Ross)          Drake
# 15                      No Guidance (feat. Drake)    Chris Brown
# 22                           No Me Conoce - Remix    Jhay Cortez
# 8                           Old Town Road - Remix      Lil Nas X
# ...

# %%
## prideti isvestini extra stulpeli, sumos, atlikti veiksmus

top_right=pd.read_excel('top1-25-2.xlsx')
top_right.head(3)
top_right['total']=top_right['Beats.Per.Minute']+top_right['Energy']+top_right['Length.']
print(top_right)
# Out:
#                                        Track.Name  Beats.Per.Minute  Energy  \
# 0                                        Senorita               117      55
# 1                                           China               105      81
# 2                   boyfriend (with Social House)               190      80
# 3                 Beautiful People (feat. Khalid)                93      65
# 4                     Goodbyes (Feat. Young Thug)               150      65
# 5               I Don't Care (with Justin Bieber)               102      68
# 6                                          Ransom               180      64
# 7                               How Do You Sleep?               111      68
# 8                           Old Town Road - Remix               136      62
# 9                                         bad guy               135      43
# 10                                       Callaita               176      62
# ...

# %%
top_right = top_right.drop(columns=['total'])
print(top_right)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-1a1fc3be33d5> in <module>
# ----> 1 top_right = top_right.drop(columns=['total'])
#       2 print(top_right)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
import pandas as pd
import numpy as np
from io import StringIO
import requests
url='https://work.studentnews.eu/s/3695/75547-European-countries-the-table-language-population-capital-currency-phone-code-internet-code.htm'

s=requests.get(url)

c=pd.read_csv(StringIO(s))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-93f995b465b2> in <module>
#       7 s=requests.get(url)
#       8
# ----> 9 c=pd.read_csv(StringIO(s))
#
# TypeError: initial_value must be str or None, not Response

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
table = pd.read_html('https://work.studentnews.eu/s/3695/75547-European-countries-the-table-language-population-capital-currency-phone-code-internet-code.htm')

# Apply head function
print(table)
table.to_excel('2_uzd.data.xlsx' )
# Out:
# [         0                                                  1   2
# 0  Country  any Austria Belgium Bulgaria Croatia Cyprus Cz... NaN
# 1      NaN                                                NaN NaN,              Staat                     Official languages    Population  \
# 0          Austria                                 German   8.4 million
# 1          Belgium  Dutch (north), French (south), German    11 million
# 2         Bulgaria                              Bulgarian     7 million
# 3          Croatia                               Croatian   4.3 million
# 4           Cyprus                         Greek, Turkish       800 000
# 5   Czech Republic                                  Czech    10 million
# 6          Denmark                                 Danish   5.6 million
# 7          Estonia                               Estonian   1.3 million
# 8          Finland                       Finnish, Swedish   5.4 million
# ...

# %%
table_3=pd.read_csv(r'https://raw.githubusercontent.com/robotautas/kursas/master/Pandas/top_20_CA_wildfires.csv')
print(table_3)
# Out:
#                   fire_name                cause      month  year  \
# 0         Mendocino Complex  Under Investigation       July  2018
# 1                    Thomas           Powerlines   December  2017
# 2                     Cedar        Human Related    October  2003
# 3                      Rush            Lightning     August  2012
# 4                       Rim        Human Related     August  2013
# 5                      Zaca        Human Related       July  2007
# 6                      Carr        Human Related       July  2018
# 7                  Matilija         Undetermined  September  1932
# 8                     Witch           Powerlines    October  2007
# 9   Klamath Theater Complex            Lightning       June  2008
# 10              Marble Cone            Lightning       July  1977
# 11                   Laguna           Powerlines  September  1970
# 12            Basin Complex            Lightning       June  2008
# ...

# %%
table_3['cause'].nunique()
# Out:
# 5

# %%
df_1=table_3['cause'].value_counts()
print(df_1)
# Out:
# Human Related          7
# Lightning              7
# Powerlines             4
# Under Investigation    1
# Undetermined           1
# Name: cause, dtype: int64

# %%
maximum_frequency=table3['year'].value_counts().idxmax()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-fb6032682e9f> in <module>
# ----> 1 maximum_frequency=table3['year'].value_counts().idxmax()
#
# NameError: name 'table3' is not defined

# %%
most_frequent=table_3['year'].value_counts().idxmax()
print(most_frequent)
# Out:
# 2018

# %%
from pandas.core.dtypes.api import is_integer
print(table_3['deaths'].astype(int).sum()) # mire is viso
# Out:
# 123

# %%
table_3 ['deaths'].astype(int).sum()
# Out:
# 123

# %%
table_3['deaths'].is_integer().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-d531bf202dc9> in <module>
# ----> 1 table_3['deaths'].is_integer().sum()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'is_integer'

# %%
table_3['deaths'].is_integer().value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-2de0caa70bc4> in <module>
# ----> 1 table_3['deaths'].is_integer().value_counts()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'is_integer'

# %%
table_3.sort_values(by='year', ascending=False)
# Out:
#                   fire_name                cause      month  year  \
# 0         Mendocino Complex  Under Investigation       July  2018
# 15                Camp Fire           Powerlines   November  2018
# 6                      Carr        Human Related       July  2018
# 1                    Thomas           Powerlines   December  2017
# 16                    Rough            Lightning       July  2015
# 4                       Rim        Human Related     August  2013
# 3                      Rush            Lightning     August  2012
# 14                  Station        Human Related     August  2009
# 9   Klamath Theater Complex            Lightning       June  2008
# 12            Basin Complex            Lightning       June  2008
# 5                      Zaca        Human Related       July  2007
# 8                     Witch           Powerlines    October  2007
# 13                 Day Fire        Human Related  September  2006
# ...

# %%
pakeisti_men=table_3.replace ({'January':1, 'February':2,'March':3,'April':4,'May':5,'June':6,'July':7,'August':8,'September':9, 'October':10, 'November':11,'December':12})

print(pakeisti_men)
# Out:
#                   fire_name                cause  month  year  \
# 0         Mendocino Complex  Under Investigation      7  2018
# 1                    Thomas           Powerlines     12  2017
# 2                     Cedar        Human Related     10  2003
# 3                      Rush            Lightning      8  2012
# 4                       Rim        Human Related      8  2013
# 5                      Zaca        Human Related      7  2007
# 6                      Carr        Human Related      7  2018
# 7                  Matilija         Undetermined      9  1932
# 8                     Witch           Powerlines     10  2007
# 9   Klamath Theater Complex            Lightning      6  2008
# 10              Marble Cone            Lightning      7  1977
# 11                   Laguna           Powerlines      9  1970
# 12            Basin Complex            Lightning      6  2008
# 13                 Day Fire        Human Related      9  2006
# ...

# %%
import pandas as pd
import requests
import io

url=('https://lt.wikipedia.org/wiki/S%C4%85ra%C5%A1as:Lietuvos_miestai_pagal_gyventojus')
s=requests. get(url). content.
c=pd. read_csv(io. StringIO(s. decode('utf-8')))
# Out:
#   File "<ipython-input-101-7f96b0fc19bc>", line 6
#     s=requests. get(url). content.
#                                   ^
# SyntaxError: invalid syntax

# %%
wiki=pd.read_html('https://lt.wikipedia.org/wiki/S%C4%85ra%C5%A1as:Lietuvos_miestai_pagal_gyventojus')

# %%
len(wiki)
# Out:
# 5

# %%
df=wiki[0]
print(df)
# Out:
#      Eilė    Miestas  2021 m.  2011 m.  2001 m.  1989 m.  1979 m.   1970 m.  \
# 0       1    Vilnius   546155   524406   542287   576747   475825  372100.0
# 1       2     Kaunas   298753   315993   378943   418087   368649  305116.0
# 2       3   Klaipėda   152008   162360   192954   202929   176648  140012.0
# 3       4   Šiauliai   100653   109328   133883   145629   118724   93057.0
# 4       5  Panevėžys    89100    99690   119749   126483   102303   73328.0
# ..    ...        ...      ...      ...      ...      ...      ...       ...
# 98     99   Užventis      600      833      898     1149     1229    1406.0
# 99    100    Dusetos      531      717      914     1185     1393    1578.0
# 100   101  Kavarskas      503      666      809      972     1113    1256.0
# 101   102  Troškūnai      389      451      525      672     1174    1434.0
# 102   103   Panemunė      217      274      329      398      506     492.0
#
#       1959 m. 1923 m.  1897 m. Tankumas (2019)
# ...

# %%
df_i = wiki.set_index('Miestas')
print(df_i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-9e0b73c432a4> in <module>
# ----> 1 df_i = wiki.set_index('Miestas')
#       2 print(df_i)
#
# AttributeError: 'list' object has no attribute 'set_index'
